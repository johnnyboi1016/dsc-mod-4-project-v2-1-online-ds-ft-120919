# %% [markdown]
# # Mod 4 Project - Time Series Modeling - Zillow US Housing Prices
#
# * Student name: John Cho
# * Student pace: full time online
# * Scheduled project review date/time:
# * Instructor name: Rafael Carrasco
# * Blog post URL:
#
#
# ### Project Question: What are the top 5 best zip codes for us to invest in?
# ## Data Import, Cleaning

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("zillow_data.csv")

# Preview data, columns, check for duplicates, null values
display(df.info(), df, f'Duplicated: {df.duplicated().sum()}')
print('Null Values:')
for col in df.columns:
    print(col, df[col].isna().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14723 entries, 0 to 14722
# Columns: 272 entries, RegionID to 2018-04
# dtypes: float64(219), int64(49), object(4)
# memory usage: 30.6+ MB
# None
#        RegionID  RegionName                 City State              Metro  \
# 0         84654       60657              Chicago    IL            Chicago
# 1         90668       75070             McKinney    TX  Dallas-Fort Worth
# 2         91982       77494                 Katy    TX            Houston
# 3         84616       60614              Chicago    IL            Chicago
# 4         93144       79936              El Paso    TX            El Paso
# ...         ...         ...                  ...   ...                ...
# 14718     58333        1338             Ashfield    MA    Greenfield Town
# 14719     59107        3293            Woodstock    NH          Claremont
# 14720     75672       40404                Berea    KY           Richmond
# ...

# %% [markdown]
# ### Dealing With Null Values:
# #### The `Metro` column appears to be the name of the 'Greater Metropolitan Area' for the specific zipcode. Filling them in with the `City` name would be fine but we can just drop this column because it is not needed for this project.
# > In fact, this goes for every non-date column except for the zipcode. After some Googling we confirmed that `RegionName` is the correct zipcode column. We'll also append the city and state to the zipcode values.

# %%
df.columns
# Out:
# Index(['RegionID', 'RegionName', 'City', 'State', 'Metro', 'CountyName',
#        'SizeRank', '1996-04', '1996-05', '1996-06',
#        ...
#        '2017-07', '2017-08', '2017-09', '2017-10', '2017-11', '2017-12',
#        '2018-01', '2018-02', '2018-03', '2018-04'],
#       dtype='object', length=272)

# %%
i = 0  #counter
for zip in df.RegionName:  #how to perform this properly using .map/apply, lambda in single line of code??
    #df.RegionName.iloc[i] = str(str(zip) + ' ' + df.City.iloc[i] + ', ' + df.State.iloc[i])
    df.iloc[i,1] = str(str(zip) + ' ' + df.iloc[i,2] + ', ' + df.iloc[i,3])
    i+=1
df.head()
# Out:
#    RegionID          RegionName      City State              Metro CountyName  \
# 0     84654   60657 Chicago, IL   Chicago    IL            Chicago       Cook
# 1     90668  75070 McKinney, TX  McKinney    TX  Dallas-Fort Worth     Collin
# 2     91982      77494 Katy, TX      Katy    TX            Houston     Harris
# 3     84616   60614 Chicago, IL   Chicago    IL            Chicago       Cook
# 4     93144   79936 El Paso, TX   El Paso    TX            El Paso    El Paso
#
#    SizeRank   1996-04   1996-05   1996-06  ...  2017-07  2017-08  2017-09  \
# 0         1  334200.0  335400.0  336500.0  ...  1005500  1007500  1007800
# 1         2  235700.0  236900.0  236700.0  ...   308000   310000   312500
# 2         3  210400.0  212200.0  212200.0  ...   321000   320600   320200
# 3         4  498100.0  500900.0  503100.0  ...  1289800  1287700  1287400
# 4         5   77300.0   77300.0   77300.0  ...   119100   119400   120000
#
# ...

# %%
# Dropping every non-date column except RegionName (rename to Zipcode)
df = df.drop(columns=['RegionID','City','State','Metro','CountyName','SizeRank'])
df = df.rename(columns={'RegionName' : 'Zipcode'})
df.head()
# Out:
#               Zipcode   1996-04   1996-05   1996-06   1996-07   1996-08  \
# 0   60657 Chicago, IL  334200.0  335400.0  336500.0  337600.0  338500.0
# 1  75070 McKinney, TX  235700.0  236900.0  236700.0  235400.0  233300.0
# 2      77494 Katy, TX  210400.0  212200.0  212200.0  210700.0  208300.0
# 3   60614 Chicago, IL  498100.0  500900.0  503100.0  504600.0  505500.0
# 4   79936 El Paso, TX   77300.0   77300.0   77300.0   77300.0   77400.0
#
#     1996-09   1996-10   1996-11   1996-12  ...  2017-07  2017-08  2017-09  \
# 0  339500.0  340400.0  341300.0  342600.0  ...  1005500  1007500  1007800
# 1  230600.0  227300.0  223400.0  219600.0  ...   308000   310000   312500
# 2  205500.0  202500.0  199800.0  198300.0  ...   321000   320600   320200
# 3  505700.0  505300.0  504200.0  503600.0  ...  1289800  1287700  1287400
# 4   77500.0   77600.0   77700.0   77700.0  ...   119100   119400   120000
#
#    2017-10  2017-11  2017-12  2018-01  2018-02  2018-03  2018-04
# ...

# %% [markdown]
# #### While observing the null values in the date columns, there appears to be decreasing 'null bunches' every 6 months, indicating certain zipcodes were missing data from earlier years. Let's confirm that by dropping all the nulls from the earliest year (1996).

# %%
# See if all nulls are removed after dropping every index row with null values from first date column only (1039 total)
df.dropna(subset=['1996-04']).isna().sum().sum()
# Out:
# 0

# %% [markdown]
# ### Great! Dropping all 1039 zipcodes would be one way of dealing with these null values. However, in case any of them are a 'top 5' candidate, that would be a bad idea. Let's instead *backfill* in these missing property values using the *next valid observation to fill gap.*

# %%
# Need to transpose dataframe (flip rows/columns) for fillna function then transpose back
df = df.T.fillna(method='bfill').T
df.isna().any().any()  #confirm no more nulls, we want False output
# Out:
# False

# %% [markdown]
# ## That should be it for the cleaning portion! Let's take a final peek at our dataframe and move onto the 'EDA' notebook.

# %%
#saving our dataframes using pickle
import pickle
with open('df.pickle', 'wb') as f:
    pickle.dump(df, f, pickle.HIGHEST_PROTOCOL)
df
# Out:
#                              Zipcode 1996-04 1996-05 1996-06 1996-07 1996-08  \
# 0                  60657 Chicago, IL  334200  335400  336500  337600  338500
# 1                 75070 McKinney, TX  235700  236900  236700  235400  233300
# 2                     77494 Katy, TX  210400  212200  212200  210700  208300
# 3                  60614 Chicago, IL  498100  500900  503100  504600  505500
# 4                  79936 El Paso, TX   77300   77300   77300   77300   77400
# ...                              ...     ...     ...     ...     ...     ...
# 14718              1338 Ashfield, MA   94600   94300   94000   93700   93400
# 14719             3293 Woodstock, NH   92700   92500   92400   92200   92100
# 14720                40404 Berea, KY   57100   57300   57500   57700   58000
# 14721  81225 Mount Crested Butte, CO  191100  192400  193700  195000  196300
# 14722             89155 Mesquite, NV  176400  176300  176100  176000  175900
#
# ...
